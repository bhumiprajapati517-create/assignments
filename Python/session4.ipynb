# %%
#task1
text = "Flipkart-sales2024"
result = text.lower().replace("-"," ")
print (result)
# Out:
# flipkart sales2024

# %%
#task2
product_name = "OnePlus Nord-CE 3"
result1 = product_name.strip()
result2 = product_name.upper()
result3 = product_name.replace("-",":")
print(result1)
print(result2)
print(result3)
# Out:
# OnePlus Nord-CE 3
# ONEPLUS NORD-CE 3
# OnePlus Nord:CE 3

# %%
#task3
code = "ZOMATO-FOOD-2024"
def split_product_code(product_code):
    return product_code.split("-")
print(split_product_code(code))
# Out:
# ['ZOMATO', 'FOOD', '2024']

# %%
#task4
text = "spotify_premium_offer"
print("character:",text[8:15])
# Out:
# character: premium

# %%
#task5
product = "Myntra shirt"
price = 799.5
print(f"deal:{product} is available at ₹{price} only!")
# Out:
# deal:Myntra shirt is available at ₹799.5 only!
