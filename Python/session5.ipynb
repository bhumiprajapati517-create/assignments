# %%
#task1
playlist_id = [101, 205, 305, 345, 555]
print(playlist_id)
# Out:
# [101, 205, 305, 345, 555]

# %%
#task2
playlist_id.append(405)
print("after append:",playlist_id)
# Out:
# after append: [101, 205, 305, 345, 555, 405, 405]

# %%
#task2
playlist_id.extend([675,897,100])
print("after extend:",playlist_id)
# Out:
# after extend: [101, 205, 305, 345, 555, 405, 405, 675, 897, 100]

# %%
#task3
playlist_id.pop(9)
print("after pop:",playlist_id)
# Out:
# after pop: [101, 205, 305, 345, 555, 405, 405, 675, 897]

# %%
#task4
insta_filter = ("khushi", "mahek", "sakshi", "bhumi")
print(insta_filter)
# Out:
# ('khushi', 'mahek', 'sakshi', 'bhumi')

# %%
insta_filter[0] = "asmita"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 insta_filter[0] = "asmita"
#
# TypeError: 'tuple' object does not support item assignment

# %%
#task5
zomato_orders = ["sandwich", "pizza", "burger"]
zomato_orders.append("pasta")
print(zomato_orders)
# Out:
# ['sandwich', 'pizza', 'burger', 'pasta']

# %%
ipl_teams = (
    "MI",
    "KKR",
    "RCB"
)
print(ipl_teams)
# Out:
# ('MI', 'KKR', 'RCB')

# %%
print("\nExplantion:")
print("List is used for zomato order because the data can change")
print("tuple is used for ipl teams because the data is fixed and immutable")
# Out:
# Explantion:
# List is used for zomato order because the data can change
# tuple is used for ipl teams because the data is fixed and immutable
