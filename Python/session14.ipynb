# %%
songs = [
    "Shape of You",
    "Blinding Lights",
    "Levitating",
    "Perfect",
    "Senorita"
]

with open("playlist.txt", "w") as file:
    for song in songs:
        file.write(song + "\n")

print("Songs written to playlist.txt")
# Out:
# Songs written to playlist.txt

# %%
with open("playlist.txt", "r") as file:
    for song in file:
        print(song.strip().upper())
# Out:
# SHAPE OF YOU
# BLINDING LIGHTS
# LEVITATING
# PERFECT
# SENORITA

# %%
import csv

with open("ipl_matches.csv", "w", newline="") as file:
    writer = csv.writer(file)

    writer.writerow(["match_id", "team1", "team2", "winner"])
    writer.writerow([1, "MI", "CSK", "CSK"])
    writer.writerow([2, "RCB", "KKR", "RCB"])
    writer.writerow([3, "GT", "RR", "GT"])

with open("ipl_matches.csv", "r") as file:
    reader = csv.DictReader(file)

    for row in reader:
        print(f"Match {row['match_id']} Winner: {row['winner']}")
# Out:
# Match 1 Winner: CSK
# Match 2 Winner: RCB
# Match 3 Winner: GT

# %%
movies = [
    {"title": "Jawan", "year": 2023, "rating": 7.0},
    {"title": "Pathaan", "year": 2023, "rating": 6.8},
    {"title": "Animal", "year": 2023, "rating": 6.5}
]

for movie in movies:
    print(f"{movie['title']} - Rating: {movie['rating']}")
# Out:
# Jawan - Rating: 7.0
# Pathaan - Rating: 6.8
# Animal - Rating: 6.5
