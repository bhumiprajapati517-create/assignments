# %%
#task1
insta_followers = {
    "bhumi":1705,
    "mahek":2103,
    "sakshi":575
}
print(insta_followers)
# Out:
# {'bhumi': 1705, 'mahek': 2103, 'sakshi': 575}

# %%
#task2
insta_followers["asmita"]=74857
print(insta_followers)
# Out:
# {'bhumi': 5017, 'sakshi': 575, 'asmita': 74857}

# %%
insta_followers["bhumi"]=5017
print(insta_followers)
# Out:
# {'bhumi': 5017, 'sakshi': 575, 'asmita': 74857}

# %%
del insta_followers["asmita"]
print(insta_followers)
# Out:
# {'bhumi': 5017, 'sakshi': 575}

# %%
#task3
food_items = {
    "sandwich" : 250,
    "pizza" : 300,
    "burger" : 350
}

print("item cost more then ₹200:")

for item,price in food_items.items():
    if price > 200:
        print(item,"-","₹" + str(price))
# Out:
# item cost more then ₹200:
# sandwich - ₹250
# pizza - ₹300
# burger - ₹350

# %%
#task4
flipcart_user = {"rahul77", "priya77", "ajay65"}
myntra_user = {"mahek77", "ajay65", "khushi90"} 

common_user = flipcart_user.intersection(myntra_user)

print("user with account on both plateform")
print(common_user)
# Out:
# user with account on both plateform
# {'ajay65'}

# %%
#task5
playlist1 = {"ARrehman", "nehakakkar", "shreyagoshal"}
playlist2 = {"shreyagoshal", "atifaslam", "arjitsingh"}

unique_user = playlist1.union(playlist2)

print("all unique artist")
print(unique_user)
# Out:
# all unique artist
# {'arjitsingh', 'nehakakkar', 'atifaslam', 'ARrehman', 'shreyagoshal'}
