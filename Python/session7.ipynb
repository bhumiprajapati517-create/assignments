# %%
#task1
listen_time = int(input("enter your spotify time (in minutes):"))

if listen_time > 120:
    print("you are true music fan")
else:
    print("keep listening")
# Out:
# enter your spotify time (in minutes): 150
# you are true music fan

# %%
#task2
amount = int(input("enter the zomato order amount:₹"))

if amount > 300:
    print("eligible for free delivery")
else:
    print("delivery charge apply")
# Out:
# enter the zomato order amount:₹ 450
# eligible for free delivery

# %%
#task3
flipkart_cart_total = int(input("enter the flipkart total discount:"))

if flipkart_cart_total > 2000:
    print("you get a 20% discount")
elif flipkart_cart_total >1000:
    print("you get a 5% discount")
else:
    print("no discount availble")
# Out:
# enter the flipkart total discount: 1500
# you get a 5% discount

# %%
#task4
ipl_team_points = int(input("enter the IPL fantasty team points:"))

if ipl_team_points > 800:
    print("champion")
elif ipl_team_points >=500 and ipl_team_points<=800:
    print("Top performer")
else:
    print("keep trying")
# Out:
# enter the IPL fantasty team points: 900
# champion
