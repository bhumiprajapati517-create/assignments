# %%
def get_song_duration_per_minute(total_duration,num_songs):
    try:
        average_duration = total_duration / num_songs
        print("average duration per songs:" ,average_duration,"minutes")
    except ZeroDivisionError:
        print("Error:number of songs cannot be zero")
    finally:
        print("calculation completed")

get_song_duration_per_minute(120,10)
# Out:
# average duration per songs: 12.0 minutes
# calculation completed

# %%
try:
    total_amount = float(input("enter total cart amount:"))
    item_count = int(input("enter number of count:"))

    price_per_item = total_amount / item_count
    print("price per item:",price_per_item)

except ZeroDivisionError:
    print("item count cannot be zero . please enter a valid number")
# Out:
# enter total cart amount: 120
# enter number of count: 20
# price per item: 6.0

# %%
class NoOffersApplied(Exception):
    pass

try:
    total_spend = float(input("Enter total spend: "))
    offers = int(input("Enter number of offers applied: "))

    if offers == 0:
        raise NoOffersApplied("No offers were applied.")

    avg_cashback = total_spend / offers
    print("Average cashback per offer:", avg_cashback)

except NoOffersApplied as e:
    print("Custom Error:", e)
# Out:
# Enter total spend:  150
# Enter number of offers applied:  30
# Average cashback per offer: 5.0

# %%
def calculate_average_rating(total_rating, num_reviews):
    try:
        return total_rating / num_reviews
    except ZeroDivisionError:
        print("Error: Number of reviews cannot be zero.")
        return None
    finally:
        print("Thank you for using the calculator")

print(calculate_average_rating(500, 0))
# Out:
# Error: Number of reviews cannot be zero.
# Thank you for using the calculator
# None

# %%
def safe_divide_for_zomato(bill_amount, num_people):
    try:
        result = bill_amount / num_people
    except ZeroDivisionError:
        print("Error: Number of people cannot be zero.")
    else:
        print("Each person should pay:", result)
    finally:
        print("Split calculation done")


safe_divide_for_zomato(1200, 4)
safe_divide_for_zomato(1200, 0)
# Out:
# Each person should pay: 300.0
# Split calculation done
# Error: Number of people cannot be zero.
# Split calculation done
