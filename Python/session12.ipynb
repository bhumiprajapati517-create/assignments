# %%
#task1
songs = ['Shape Of You', 'Blinding Lights', 'Levitating', 'Senorita']
lowercase_song = list(map(lambda song : song.lower(),songs))
print(lowercase_song)
# Out:
# ['shape of you', 'blinding lights', 'levitating', 'senorita']

# %%
#task2
ratings =  [4.2, 3.8, 4.5, 2.9, 3.5]
high_rates = list(filter(lambda rating : rating > 4.0, ratings))
print(high_rates)
# Out:
# [4.2, 4.5]

# %%
#task3
from functools import reduce

cart = [499, 1299, 299, 799]

total = reduce(lambda x, y: x + y, cart)

print("Total Price:", total)
# Out:
# Total Price: 2896

# %%
#task4
def format_followers(count):
    if count >= 1000000:
        return f"{count/1000000:.1f}M"
    elif count >= 1000:
        return f"{count/1000:.1f}K"
    else:
        return str(count)

followers = [950, 1500, 25000, 1200000]

formatted = list(map(format_followers, followers))

print(formatted)
# Out:
# ['950', '1.5K', '25.0K', '1.2M']

# %%
#task5
scores = [101, 98, 120, 77, 88]

even_scores = list(filter(lambda score: score % 2 == 0, scores))

print(even_scores)
# Out:
# [98, 120, 88]
