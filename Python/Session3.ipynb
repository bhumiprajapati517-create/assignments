# %%
#task1
age = 22
height = 67.00
name = "bhumi"
spotify_account = True
print("age:",age)
print("height:",height)
print("name:",name)
print("spotify_account:",spotify_account)
print("type of age:",type(age))
print("type of height:",type(height))
print("type of name:",type(name))
print("type of spotify_account:",type(spotify_account))
# Out:
# age: 22
# height: 67.0
# name: bhumi
# spotify_account: True
# type of age: <class 'int'>
# type of height: <class 'float'>
# type of name: <class 'str'>
# type of spotify_account: <class 'bool'>

# %%
#task2
cart_price = ['199.99', '49', '350.75']
def total_cart_amount(prices):
    total = 0.0
    for price in prices:
        total += float(price)
    return total

print("total_cart_amount:",total_cart_amount(cart_price))
# Out:
# total_cart_amount: 599.74

# %%
#task4
score = input("enter your cricket score")
score = int(score)
if score >= 50:
    print("half century")
else:
     print("keep going")
# Out:
# enter your cricket score 56
# half century

# %%
#task4
is_premium = 'True'
is_premium = (is_premium == "True")
print(is_premium)
print(type(is_premium))
# Out:
# True
# <class 'bool'>
